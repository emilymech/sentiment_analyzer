# %% [markdown]
# Sentiment Analysis - Emily Mech
#
# This script runs classifies movie reviews as positive or negative. Several models and feature/text representations are run to examine which representations lead to the best classification. The output of this script is "results.csv" in the src/Results folder which can be used to compare model performance. As this program is running 36 models, it takes about 30min to run. If you would like to change any of the text preprocessing steps, this can be done in the init function of the Classify class in sentiment_analyzer.ipynb.

# %%
from ipynb.fs.full.sentiment_analyzer import Preprocess, Classify

# %%
def main():
    classify = Classify()
    output_dict_list = classify.run_classifiers()
    classify.save_output(output_dict_list)

main()
# Out:
# Now classifying...
# classifier:Logistic_Regression, text:raw, vect:tfidf, feature:baseline
# 	Average Macro F1 for Logistic_Regression:		 0.618811521955845
# 	Average Macro Precision for Logistic_Regression:	 0.5636288484180465
# 	Average Macro Recall for Logistic_Regression:		 0.32275
# Now classifying...
# classifier:Decision_Tree, text:raw, vect:tfidf, feature:baseline
# 	Average Macro F1 for Decision_Tree:		 0.6708853747701022
# 	Average Macro Precision for Decision_Tree:	 0.527002700270027
# 	Average Macro Recall for Decision_Tree:		 0.33299999999999996
# Now classifying...
# classifier:Neural_Network, text:raw, vect:tfidf, feature:baseline
# 	Average Macro F1 for Neural_Network:		 0.5107796697434855
# 	Average Macro Precision for Neural_Network:	 0.3674315619967794
# 	Average Macro Recall for Neural_Network:		 0.31775
# Now classifying...
# classifier:Logistic_Regression, text:raw, vect:tfidf, feature:improved
# 	Average Macro F1 for Logistic_Regression:		 0.5889810975958445
# ...
